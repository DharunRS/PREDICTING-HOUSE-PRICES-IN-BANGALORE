# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r"D:\intern\bangalore_data_final.csv")  # Update path if needed

# Dataset Overview
print(" Dataset Overview:")
print(df.info())

# First 5 Rows
print("\n First 5 Rows:")
print(df.head())

# Summary Statistics
print("\n Summary Statistics:")
print(df.describe())

# Missing Values
print("\n Missing Values:")
print(df.isnull().sum())

# Unique Values Per Column
print("\n Unique Values Per Column:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()}")

# Plotting Distributions
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("\n Plotting Distributions...")
for col in numeric_cols:
    plt.figure(figsize=(6, 3))
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()
# Out:
#  Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13306 entries, 0 to 13305
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   area_type          13306 non-null  float64
#  1   availability       13306 non-null  int64
#  2   location           13306 non-null  int64
#  3   BHK                13306 non-null  int64
#  4   society            13306 non-null  int64
#  5   total_sqft         13306 non-null  float64
#  6   bath               13306 non-null  int64
#  7   balcony            13306 non-null  int64
#  8   price              13306 non-null  float64
#  9   price_per_sqft     13306 non-null  float64
#  10  property_category  13306 non-null  int64
#  11  budget_category    13306 non-null  int64
#  12  total_rooms        13306 non-null  int64
#  13  bhk_bath_ratio     13306 non-null  int64
#  14  location_enc       13306 non-null  int64
#  15  area_price_rank    13306 non-null  int64
#  16  area_price_zone    13306 non-null  int64
# dtypes: float64(4), int64(13)
# memory usage: 1.7 MB
# None
#
#  First 5 Rows:
#    area_type  availability  location  BHK  society  total_sqft  bath  balcony  \
# 0        3.0            80       417    2      464      1056.0     2        1
# 1        2.0            80       315    4     2439      2550.0     4        3
# 2        0.5            80      1175    3      806      1440.0     2        3
# 3        3.0            80       755    3     2186      1521.0     3        1
# 4        3.0            80       714    2      806      1200.0     2        1
#
#         price  price_per_sqft  property_category  budget_category  \
# 0   3907000.0         3699.81                  2                2
# 1  12000000.0         4705.88                  0                3
# 2   6200000.0         4305.56                  1                1
# 3   9500000.0         6245.89                  1                1
# 4   5100000.0         4250.00                  2                1
#
#    total_rooms  bhk_bath_ratio  location_enc  area_price_rank  area_price_zone
# 0            5               1           654                1                1
# 1           11               1           541                4                3
# 2            8               1           197                3                0
# 3            7               1          1029                1                1
# 4            5               1           984                1                1
#
#  Summary Statistics:
#           area_type  availability      location           BHK       society  \
# count  13306.000000       13306.0  13306.000000  13306.000000  13306.000000
# mean       2.381595          80.0    670.068691      2.655494   1129.015707
# std        0.964523           0.0    364.119308      0.814413    626.630486
# min        0.500000          80.0      0.000000      1.000000      0.000000
# 25%        2.000000          80.0    396.000000      2.000000    806.000000
# 50%        3.000000          80.0    651.500000      3.000000    806.000000
# 75%        3.000000          80.0    995.000000      3.000000   1586.000000
# max        3.000000          80.0   1299.000000      4.000000   2687.000000
#
#          total_sqft          bath       balcony         price  price_per_sqft  \
# count  13306.000000  13306.000000  13306.000000  1.330600e+04    13306.000000
# mean    1428.026542      2.527882      1.603938  9.327872e+06     6168.548270
# std      528.940139      0.840722      0.802605  5.967456e+06     2522.631619
# min      230.000000      1.000000      0.000000  8.000000e+05      500.000000
# 25%     1100.000000      2.000000      1.000000  5.000000e+06     4292.492500
# 50%     1275.000000      2.000000      2.000000  7.200000e+06     5500.000000
# 75%     1680.000000      3.000000      2.000000  1.200000e+07     7547.972500
# max     2550.000000      4.000000      3.000000  2.250000e+07    12431.192500
#
#        property_category  budget_category   total_rooms  bhk_bath_ratio  \
# count       13306.000000     13306.000000  13306.000000         13306.0
# mean            1.353675         1.371186      6.787314             1.0
# std             0.833695         0.921239      1.978807             0.0
# min             0.000000         0.000000      2.000000             1.0
# 25%             1.000000         1.000000      5.000000             1.0
# 50%             1.000000         1.000000      7.000000             1.0
# 75%             2.000000         2.000000      8.000000             1.0
# max             3.000000         3.000000     11.000000             1.0
#
#        location_enc  area_price_rank  area_price_zone
# count  13306.000000     13306.000000     13306.000000
# mean     644.981587         1.823463         1.127311
# std      363.160327         1.189972         0.881406
# min        0.000000         1.000000         0.000000
# 25%      288.000000         1.000000         1.000000
# 50%      658.000000         1.000000         1.000000
# 75%      932.000000         3.000000         1.000000
# max     1299.000000         4.000000         3.000000
#
#  Missing Values:
# area_type            0
# availability         0
# location             0
# BHK                  0
# society              0
# total_sqft           0
# bath                 0
# balcony              0
# price                0
# price_per_sqft       0
# property_category    0
# budget_category      0
# total_rooms          0
# bhk_bath_ratio       0
# location_enc         0
# area_price_rank      0
# area_price_zone      0
# dtype: int64
#
#  Unique Values Per Column:
# area_type: 4
# availability: 1
# location: 1300
# BHK: 4
# society: 2688
# total_sqft: 1554
# bath: 4
# balcony: 4
# price: 1716
# price_per_sqft: 6574
# property_category: 4
# budget_category: 4
# total_rooms: 10
# bhk_bath_ratio: 1
# location_enc: 1300
# area_price_rank: 4
# area_price_zone: 4
#
#  Plotting Distributions...

# %% [markdown]
# # Boxplots for Outlier Detection

# %%
# Boxplots for Outlier Detection
print("\n📦 Plotting Boxplots for Outlier Detection...")
for col in numeric_cols:
    plt.figure(figsize=(6, 3))
    sns.boxplot(data=df, x=col, color='orange')
    plt.title(f"Boxplot of {col}")
    plt.tight_layout()
    plt.show()
# Out:
# 📦 Plotting Boxplots for Outlier Detection...

# %%
# Correlation Heatmap
plt.figure(figsize=(13, 10))
corr_matrix = df[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=1)
plt.title(" Correlation Heatmap")
plt.tight_layout()
plt.show()
